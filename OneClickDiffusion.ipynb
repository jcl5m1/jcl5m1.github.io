# %% [markdown]
# <a href="https://colab.research.google.com/github/jcl5m1/jcl5m1.github.io/blob/main/OneClickDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Sat Feb 18 06:26:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    39W / 300W |      0MiB / 16384MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install --upgrade fastapi==0.90.0
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !curl -Lo urpm.ckpt https://huggingface.co/nolanaatama/urpmu/resolve/main/urpm2.ckpt
# !mv "/content/urpm.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"
# openpose
# !curl -Lo control_openpose-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors
# !mv "/content/control_openpose-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
#

import shutil
shutil.rmtree('/content/stable-diffusion-webui/embeddings')
# %cd /content/stable-diffusion-webui
# !git clone https://huggingface.co/nolanaatama/embeddings
  

# %cd /content/stable-diffusion-webui
# !git checkout 91c8d0d
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --xformers --reinstall-xformers --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
# Out:
# Streaming output truncated to the last 5000 lines.
#  75% 12/16 [00:01<00:00,  7.70it/s]
#  81% 13/16 [00:01<00:00,  7.33it/s]
#  88% 14/16 [00:01<00:00,  7.32it/s]
#  94% 15/16 [00:01<00:00,  7.30it/s]
# 100% 16/16 [00:01<00:00,  8.02it/s]
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  7.08it/s]
#  12% 2/16 [00:00<00:01,  7.10it/s]
#  19% 3/16 [00:00<00:01,  7.07it/s]
#  25% 4/16 [00:00<00:01,  6.74it/s]
#  31% 5/16 [00:00<00:01,  6.42it/s]
#  38% 6/16 [00:00<00:01,  6.20it/s]
#  44% 7/16 [00:01<00:01,  6.32it/s]
#  50% 8/16 [00:01<00:01,  6.68it/s]
#  56% 9/16 [00:01<00:01,  6.79it/s]
#  62% 10/16 [00:01<00:00,  6.99it/s]
#  69% 11/16 [00:01<00:00,  7.21it/s]
#  75% 12/16 [00:01<00:00,  6.82it/s]
#  81% 13/16 [00:01<00:00,  6.84it/s]
#  88% 14/16 [00:02<00:00,  6.52it/s]
#  94% 15/16 [00:02<00:00,  6.60it/s]
# 100% 16/16 [00:02<00:00,  6.54it/s]
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  5.14it/s]
#  12% 2/16 [00:00<00:02,  5.29it/s]
# ...
